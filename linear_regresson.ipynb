# %% [markdown]
# # Predicting Rice Prices Using Linear Regression Algorithm

# %%
# import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the dataset
df=pd.read_csv("D:/ML_assessment4/imputed_processed_data.csv")
df
# Out:
#           date   price  anuradhapura_producer_price  \
# 0     1/1/1996   18.07                         7.75
# 1     2/1/1996   18.70                         8.17
# 2     3/1/1996   18.49                         7.95
# 3     4/1/1996   18.52                         8.25
# 4     5/1/1996   19.02                         8.38
# ..         ...     ...                          ...
# 319   8/1/2022  239.24                       112.60
# 320   9/1/2022  228.44                       110.50
# 321  10/1/2022  224.78                       105.48
# 322  11/1/2022  222.28                        98.40
# 323  12/1/2022  218.20                        98.15
#
#      kurunegala_producer_price  polonnaruwa_producer_price  production  \
# 0                        7.900                        8.18    1333.600
# 1                        8.260                        8.76    1333.600
# 2                        7.850                        7.99    1333.600
# 3                        8.010                        8.29    1333.600
# 4                        8.500                        8.34     731.500
# ..                         ...                         ...         ...
# 319                    113.863                      122.93    1461.675
# 320                    108.008                      117.00    1461.675
# 321                    106.740                      109.50    1931.200
# 322                    101.900                      103.48    1931.200
# 323                    101.440                      102.53    1931.200
#
#      production_total  exchange_rate  fuel_price       m0        m2       m1  \
# 0            2065.100         53.685        12.4    77071    228090    73783
# 1            2065.100         53.685        12.4    79586    234199    77440
# 2            2065.100         53.685        12.4    82915    239178    81796
# 3            2065.100         54.735        12.4    80873    241893    79478
# 4            2065.100         54.950        12.4    83410    242072    76620
# ..                ...            ...         ...      ...       ...      ...
# 319          3392.875        357.880       430.0  1386248  10285938  1534114
# 320          3392.875        365.500       430.0  1378579  10351444  1528595
# 321          3392.875        363.000       430.0  1341681  10338384  1456688
# 322          3392.875        368.500       430.0  1318493  10416961  1457977
# 323          3392.875        367.500       420.0  1349389  10497052  1453597
#
#           m2b
# 0      260481
# 1      269496
# 2      272552
# 3      278425
# 4      277365
# ..        ...
# 319  11986911
# 320  12051480
# 321  12045719
# 322  12162934
# 323  12289637
#
# [324 rows x 13 columns]

# %%
# Extract features and target variable
features = df.drop(columns=['price', 'date', 'm0', 'm1', 'm2', 'm2b'])
target = df['price']


# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Initialize and train the Linear Regression model
linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)

# Predict on the test set
y_pred = linear_regression.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Squared error value  : " , mse)
print("Mean Absolute error value : " , mae)
print("Mean Square root value    : " , rmse)
print("Mean R Squared value      : " , r2)

# Scatter plot of Actual vs Predicted prices
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', linewidth=2)
plt.grid(True)
plt.show()
# Out:
# Mean Squared error value  :  20.57172651579252
# Mean Absolute error value :  3.57237504081559
# Mean Square root value    :  4.535606521270614
# Mean R Squared value      :  0.9886180517840043
